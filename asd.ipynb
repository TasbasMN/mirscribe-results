# %%
import os
import shutil

# %%
def find_results_csv(root_folder, prefix='2'):
    """
    Crawls through folders and their subfolders to find CSV files starting with 'results_'
    when parent folder starts with given prefix
    
    Args:
        root_folder (str): The root directory path to start searching from
        prefix (str): Prefix for folder names to search in (default: '2')
        
    Returns:
        list: List of full file paths for matching CSV files
    """
    csv_files = []
    
    try:
        for root, dirs, files in os.walk(root_folder):
            if os.path.basename(root).startswith(prefix):
                # Once we find a folder with prefix, search it and all its subfolders
                for subroot, subdirs, subfiles in os.walk(root):
                    for file in subfiles:
                        if file.startswith('results_') and file.endswith('.csv'):
                            csv_files.append(os.path.join(subroot, file))
        return csv_files
        
    except Exception as e:
        print(f"Error occurred while searching: {e}")
        return []

def extract_pd_values(filepath_list):
    """
    Extracts PD values (like PD4841a) from file paths, removing 'results_', '.csv' and '+'
    
    Args:
        filepath_list (list): List of file paths
        
    Returns:
        list: List of extracted PD values
    """
    pd_values = []
    for path in filepath_list:
        pd = path.split('/')[-1].replace('results_', '').replace('.csv', '').replace('+', '')
        pd_values.append(pd)
    
    return pd_values


def move_csvs_to_target(filepath_list, target_folder):
    """
    Moves CSV files from source paths to target folder
    
    Args:
        filepath_list (list): List of source CSV file paths
        target_folder (str): Destination folder path
    """
    # Create target folder if it doesn't exist
    os.makedirs(target_folder, exist_ok=True)
    
    for source_path in filepath_list:
        # Get just the filename from the path
        filename = os.path.basename(source_path)
        # Create destination path
        dest_path = os.path.join(target_folder, filename)
        
        try:
            shutil.move(source_path, dest_path)
            print(f"Moved {filename} to {target_folder}")
        except Exception as e:
            print(f"Error moving {source_path}: {e}")

# Example usage:
# move_csvs_to_target(filepath_list, "path/to/target/folder")

# %%
res_2 = find_results_csv('downloads/all/results', prefix='2')
downloads_2 = extract_pd_values(res_2)

move_csvs_to_target(res_2, 'downloads/2')
# Out:
# Moved results_PD4116a+.csv to downloads/2
# Moved results_PD14465a+.csv to downloads/2
# Moved results_PD13623a+.csv to downloads/2
# Moved results_PD11396a+.csv to downloads/2
# Moved results_PD18269a+.csv to downloads/2
# Moved results_PD11348a+.csv to downloads/2
# Moved results_PD13298a+.csv to downloads/2
# Moved results_PD3890a+.csv to downloads/2
# Moved results_PD11372a+.csv to downloads/2
# Moved results_PD18730a+.csv to downloads/2
# Moved results_PD4194a+.csv to downloads/2
# Moved results_PD4006a+.csv to downloads/2
# Moved results_PD11366a+.csv to downloads/2
# Moved results_PD14450a+.csv to downloads/2
# Moved results_PD11385a+.csv to downloads/2
# Moved results_PD4103a+.csv to downloads/2
# Moved results_PD11761a+.csv to downloads/2
# Moved results_PD4115a+.csv to downloads/2
# Moved results_PD13755a+.csv to downloads/2
# Moved results_PD11336a+.csv to downloads/2
# Moved results_PD14432a+.csv to downloads/2
# Moved results_PD3904a+.csv to downloads/2
# Moved results_PD11757a+.csv to downloads/2
# Moved results_PD13299a+.csv to downloads/2
# Moved results_PD11365a+.csv to downloads/2
# Moved results_PD11376a+.csv to downloads/2
# Moved results_PD13626a+.csv to downloads/2
# Moved results_PD13765a+.csv to downloads/2
# Moved results_PD13296a+.csv to downloads/2
# Moved results_PD11379a+.csv to downloads/2
# Moved results_PD13427a+.csv to downloads/2
# Moved results_PD17973a+.csv to downloads/2
# Moved results_PD14472a+.csv to downloads/2
# Moved results_PD14454a+.csv to downloads/2
# Moved results_PD13753a+.csv to downloads/2
# Moved results_PD18264a+.csv to downloads/2
# Moved results_PD13757a+.csv to downloads/2
# Moved results_PD18048a+.csv to downloads/2
# Moved results_PD3905a+.csv to downloads/2
# Moved results_PD14433a+.csv to downloads/2
# Moved results_PD13168a+.csv to downloads/2
# Moved results_PD18049a+.csv to downloads/2
# Moved results_PD13163a+.csv to downloads/2
# Moved results_PD11743a+.csv to downloads/2
# Moved results_PD11359a+.csv to downloads/2
# Moved results_PD18116a+.csv to downloads/2
# Moved results_PD18771a+.csv to downloads/2
# Moved results_PD3945a+.csv to downloads/2
# Moved results_PD4198a+.csv to downloads/2
# Moved results_PD11341a+.csv to downloads/2
# Moved results_PD4088a+.csv to downloads/2
# Moved results_PD14456a+.csv to downloads/2
# Moved results_PD3851a+.csv to downloads/2
# Moved results_PD18257a+.csv to downloads/2
# Moved results_PD4086a+.csv to downloads/2
# Moved results_PD4005a+.csv to downloads/2
# Moved results_PD18031a+.csv to downloads/2
# Moved results_PD13625a+.csv to downloads/2
# Moved results_PD11360a+.csv to downloads/2
# Moved results_PD13304a+.csv to downloads/2
# Moved results_PD18020a+.csv to downloads/2
# Moved results_PD13618a+.csv to downloads/2
# Moved results_PD4107a+.csv to downloads/2
# Moved results_PD18733a+.csv to downloads/2
# Moved results_PD11402a+.csv to downloads/2
# Moved results_PD18259a+.csv to downloads/2
# Moved results_PD4120a+.csv to downloads/2
# Moved results_PD11395a+.csv to downloads/2
# Moved results_PD14460a+.csv to downloads/2
# Moved results_PD13606a+.csv to downloads/2
# Moved results_PD18017a+.csv to downloads/2
# Moved results_PD4248a+.csv to downloads/2
# Moved results_PD11398a+.csv to downloads/2
# Moved results_PD11752a+.csv to downloads/2
# Moved results_PD4085a+.csv to downloads/2
# Moved results_PD11740a+.csv to downloads/2
# Moved results_PD13627a+.csv to downloads/2
# Moved results_PD13767a+.csv to downloads/2
# Moved results_PD11361a+.csv to downloads/2
# Moved results_PD17981a+.csv to downloads/2
# Moved results_PD11386a+.csv to downloads/2
# Moved results_PD4109a+.csv to downloads/2
# Moved results_PD14462a+.csv to downloads/2
# Moved results_PD13420a+.csv to downloads/2
# Moved results_PD13609a+.csv to downloads/2
# Moved results_PD4192a+.csv to downloads/2
# Moved results_PD14457a+.csv to downloads/2
# Moved results_PD11751a+.csv to downloads/2
# Moved results_PD4199a+.csv to downloads/2
# Moved results_PD11358a+.csv to downloads/2
# Moved results_PD11753a+.csv to downloads/2
# Moved results_PD13762a+.csv to downloads/2

# %%
from pathlib import Path

def get_vcf_basenames(folder_path):
    """
    Finds all VCF files in folder and subfolders and returns list of basenames without .vcf extension
    """
    folder = Path(folder_path)
    vcf_list = [f.stem for f in folder.rglob('*.csv')]
    return sorted(vcf_list)


basenames_2 = get_vcf_basenames('downloads/2')

# %%
import pandas as pd

df = pd.read_parquet("results/2/results_PD4076a+.parquet")

df.head()
# Out:
#                                      id  wt_prediction  mut_prediction  \
# 0  PD4076a_X_100480810_G_A_MIMAT0000067       0.659048        0.416123
# 1  PD4076a_X_100480810_G_A_MIMAT0000082       0.825714        0.475650
# 2  PD4076a_X_100480810_G_A_MIMAT0000083       0.854318        0.499602
# 3  PD4076a_X_100480810_G_A_MIMAT0000091       0.717076        0.304212
# 4  PD4076a_X_100480810_G_A_MIMAT0000094       0.680380        0.444619
#
#    pred_difference   vcf_id mirna_accession          gene_id  is_intron  \
# 0           -0.243  PD4076a    MIMAT0000067  ENSG00000102385       True
# 1           -0.350  PD4076a    MIMAT0000082  ENSG00000102385       True
# 2           -0.355  PD4076a    MIMAT0000083  ENSG00000102385       True
# 3           -0.413  PD4076a    MIMAT0000091  ENSG00000102385       True
# 4           -0.236  PD4076a    MIMAT0000094  ENSG00000102385       True
#
#   mutation_context       mutsig_key  is_gene_upregulated
# 0          A[C>T]C  PD4076a_A[C>T]C                 True
# 1          A[C>T]C  PD4076a_A[C>T]C                 True
# 2          A[C>T]C  PD4076a_A[C>T]C                 True
# 3          A[C>T]C  PD4076a_A[C>T]C                 True
# 4          A[C>T]C  PD4076a_A[C>T]C                 True
